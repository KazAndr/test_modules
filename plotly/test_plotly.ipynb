# %%
# plotly standard imports
import plotly.graph_objs as go
import plotly.plotly as py

# Cufflinks wrapper on plotly
import cufflinks as cf

# Data science imports
import pandas as pd
import numpy as np

# %matplotlib inline

# Options for pandas
pd.options.display.max_columns = 30

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)
cf.go_offline(connected=True)

# Set global theme
cf.set_config_file(world_readable=True, theme='pearl')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_parquet('https://github.com/WillKoehrsen/Data-Analysis/blob/master/plotly/data/medium_data_2019_01_06?raw=true')
df.head()

_ = df['claps'].plot.hist()
_ = df.plot(x='fans', y='word_count', kind='scatter')
# Out:
#      claps  days_since_publication  fans  \
# 119      2              574.858594     2
# 118     18              567.540639     3
# 121     50              554.920762    19
# 122      0              554.078160     0
# 114      0              550.090507     0
#
#                                                   link  num_responses  \
# 119  https://medium.com/p/screw-the-environment-but...              0
# 118  https://medium.com/p/the-vanquishing-of-war-pl...              0
# 121  https://medium.com/p/capstone-project-mercedes...              0
# 122  https://medium.com/p/home-of-the-scared-5af0fe...              0
# 114  https://medium.com/p/the-triumph-of-peace-f485...              0
#
#     publication      published_date  read_ratio  read_time  reads  \
# 119        None 2017-06-10 14:25:00       41.98          7     68
# 118        None 2017-06-17 22:02:00       32.93         14     54
# 121        None 2017-06-30 12:55:00       20.19         42    215
# 122        None 2017-07-01 09:08:00       35.85          9     19
# 114        None 2017-07-05 08:51:00        8.77         14      5
#
#            started_date                                           tags  \
# 119 2017-06-10 14:24:00                    [Climate Change, Economics]
# 118 2017-06-17 22:02:00  [Climate Change, Humanity, Optimism, History]
# 121 2017-06-30 12:00:00    [Machine Learning, Python, Udacity, Kaggle]
# 122 2017-06-30 18:21:00       [Politics, Books, News, Media Criticism]
# 114 2017-07-03 20:18:00         [Books, Psychology, History, Humanism]
#
#                                                   text  \
# 119  Screw the Environment, but Consider Your Walle...
# 118  The Vanquishing of War, Plague and Famine Part...
# 121  Capstone Project: Mercedes-Benz Greener Manufa...
# 122  Home of the Scared A review of A Culture of Fe...
# 114  The Triumph of Peace A review of The Better An...
#
#                                                  title  title_word_count  \
# 119    Screw the Environment, but Consider Your Wallet                 8
# 118          The Vanquishing of War, Plague and Famine                 8
# 121  Capstone Project: Mercedes-Benz Greener Manufa...                 7
# 122                                 Home of the Scared                 4
# 114                               The Triumph of Peace                 4
#
#           type  views  word_count  claps_per_word  editing_days  \
# 119  published    162        1859        0.001076             0
# 118  published    164        3891        0.004626             0
# 121  published   1065       12025        0.004158             0
# 122  published     53        2533        0.000000             0
# 114  published     57        3892        0.000000             1
#
#      <tag>Education  <tag>Data Science  <tag>Towards Data Science  \
# 119               0                  0                          0
# 118               0                  0                          0
# 121               0                  0                          0
# 122               0                  0                          0
# 114               0                  0                          0
#
#      <tag>Machine Learning  <tag>Python
# 119                      0            0
# 118                      0            0
# 121                      1            1
# 122                      0            0
# 114                      0            0

# %%
df['claps'].iplot(
    kind='hist',
    bins=30,
    xTitle='claps',
    linecolor='black',
    yTitle='count',
    title='Claps Distribution')
# Out:
# <div id="95738bfd-e7df-455d-9957-d13c7daab462" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("95738bfd-e7df-455d-9957-d13c7daab462", [{"opacity": 0.8, "uid": "6bfe5bec-2962-11e9-8506-001b11c4043c", "histfunc": "count", "nbinsx": 30, "x": [2, 18, 50, 0, 0, 0, 73, 234, 2, 0, 682, 58, 5, 7, 87, 23, 4, 113, 8, 17, 8, 4800, 2700, 72, 123, 857, 186, 11, 119, 2000, 4100, 59, 2700, 77, 14, 7000, 1200, 275, 1600, 1600, 1000, 4300, 4980, 12900, 223, 4900, 101, 5900, 548, 895, 6700, 6500, 2700, 1100, 2900, 2600, 2800, 5300, 1300, 1000, 7900, 364, 13500, 4100, 2200, 3900, 6300, 8200, 1300, 5400, 2300, 2700, 2100, 707, 650, 2700, 4100, 822, 830, 3700, 653, 657, 1100, 2800, 3100, 792, 222, 3300, 315, 2500, 976, 2000, 1000, 3200, 651, 2300, 809, 745, 587, 818, 2200, 1300, 630, 2600, 2000, 3600, 440, 728, 893, 205, 529, 121, 361, 31, 0, 24, 0, 5, 6, 0, 424, 443, 412, 329, 309, 75], "type": "histogram", "name": "claps", "orientation": "v", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#000000", "width": 1.3}}, "histnorm": ""}], {"title": "Claps Distribution", "titlefont": {"color": "#4D5663"}, "plot_bgcolor": "#F5F6F9", "barmode": "overlay", "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "yaxis": {"title": "count", "tickfont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "linecolor": "black", "gridcolor": "#E1E5ED", "showgrid": true, "titlefont": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "xaxis": {"title": "claps", "tickfont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "linecolor": "black", "gridcolor": "#E1E5ED", "showgrid": true, "titlefont": {"color": "#4D5663"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
df['claps'].iplot(
    kind='hist',
    bins=30,
    xTitle='reads',
    linecolor='black',
    histnorm='percent',
    yTitle='percentage (%)',
    title='Reads Distribution in Percent')
# Out:
# <div id="2ba92c56-9f8d-4b3b-b8ed-d57b141901a1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2ba92c56-9f8d-4b3b-b8ed-d57b141901a1", [{"opacity": 0.8, "uid": "a6c13cee-2a2a-11e9-b00a-001b11c4043c", "histfunc": "count", "nbinsx": 30, "x": [2, 18, 50, 0, 0, 0, 73, 234, 2, 0, 682, 58, 5, 7, 87, 23, 4, 113, 8, 17, 8, 4800, 2700, 72, 123, 857, 186, 11, 119, 2000, 4100, 59, 2700, 77, 14, 7000, 1200, 275, 1600, 1600, 1000, 4300, 4980, 12900, 223, 4900, 101, 5900, 548, 895, 6700, 6500, 2700, 1100, 2900, 2600, 2800, 5300, 1300, 1000, 7900, 364, 13500, 4100, 2200, 3900, 6300, 8200, 1300, 5400, 2300, 2700, 2100, 707, 650, 2700, 4100, 822, 830, 3700, 653, 657, 1100, 2800, 3100, 792, 222, 3300, 315, 2500, 976, 2000, 1000, 3200, 651, 2300, 809, 745, 587, 818, 2200, 1300, 630, 2600, 2000, 3600, 440, 728, 893, 205, 529, 121, 361, 31, 0, 24, 0, 5, 6, 0, 424, 443, 412, 329, 309, 75], "type": "histogram", "name": "claps", "orientation": "v", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#000000", "width": 1.3}}, "histnorm": "percent"}], {"title": "Reads Distribution in Percent", "titlefont": {"color": "#4D5663"}, "plot_bgcolor": "#F5F6F9", "barmode": "overlay", "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "yaxis": {"title": "percentage (%)", "tickfont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "linecolor": "black", "gridcolor": "#E1E5ED", "showgrid": true, "titlefont": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "xaxis": {"title": "reads", "tickfont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "linecolor": "black", "gridcolor": "#E1E5ED", "showgrid": true, "titlefont": {"color": "#4D5663"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go
import plotly.io as pio
import plotly as pl

import os
import numpy as np

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sz = np.random.rand(N)*30

fig = go.Figure()
fig.add_scatter(x=x,
                y=y,
                mode='markers',
                marker={'size': sz,
                        'color': colors,
                        'opacity': 0.6,
                        'colorscale': 'Viridis'
                       });
iplot(fig)
# Out:
# Scatter({
#     'marker': {'color': array([0.19700265, 0.54182656, 0.68814604, 0.43909611, 0.05412889, 0.64012146,
#                                0.50414199, 0.14602732, 0.45817683, 0.23031517, 0.49167694, 0.7805904 ,
#                                0.3683899 , 0.14259022, 0.14566501, 0.22388716, 0.18535734, 0.53782356,
#                                0.07749536, 0.50841686, 0.15924798, 0.67293173, 0.6634371 , 0.04503073,
#                                0.49437989, 0.64875337, 0.06136625, 0.44097072, 0.72672805, 0.24884925,
#                                0.79851631, 0.89246826, 0.84181664, 0.53769361, 0.57280504, 0.95570291,
#                                0.8340478 , 0.81981311, 0.1526392 , 0.46075866, 0.65462906, 0.68159173,
#                                0.78209273, 0.34171597, 0.29672554, 0.20532183, 0.56180584, 0.23316687,
#                                0.5188701 , 0.44435536, 0.08797346, 0.23888909, 0.35533399, 0.51105825,
#                                0.18174225, 0.36671853, 0.54992623, 0.35365283, 0.68208607, 0.10210473,
#                                0.22524088, 0.17771448, 0.70177178, 0.74345278, 0.45204929, 0.26299144,
#                                0.29902639, 0.11377888, 0.53208414, 0.31845516, 0.69304962, 0.65658154,
#                                0.52454691, 0.27030391, 0.56450968, 0.7197265 , 0.65635835, 0.83906565,
#                                0.38056103, 0.97686094, 0.94731816, 0.33570055, 0.36084296, 0.28977339,
#                                0.16725972, 0.32553296, 0.56275983, 0.69079727, 0.46640483, 0.47989877,
#                                0.97035872, 0.39318233, 0.34193406, 0.94517735, 0.48092275, 0.8041914 ,
#                                0.42631167, 0.84760641, 0.76202537, 0.94351868]),
#                'colorscale': 'Viridis',
#                'opacity': 0.6,
#                'size': array([13.16332521,  4.59729583, 15.09605735,  8.40368194, 29.83891357,
#                               18.94489611, 14.80328571,  3.97392972,  6.15509335,  8.06356844,
#                               19.73863566, 19.9157636 ,  2.86578877,  1.72264708,  8.88909865,
#                               16.15370281, 26.58199766,  4.08530605,  8.62113085, 12.08465595,
#                                0.52810905, 23.74897854, 11.01881047,  2.821737  , 20.42194346,
#                               27.13311743, 17.88235262,  1.25692329, 21.01897429,  3.0333762 ,
#                               23.03743269, 10.0563397 , 23.47192314,  5.01265216,  6.23450303,
.21668861481732227, 0.027959327448604077, 0.027518988129846655, 0.9006551807550673, 0.48269279174921464, 0.07659690765778093, 0.11948532462152717, 0.07933156984241374, 0.5830171003646919, 0.19542705753399925, 0.6950621386468333, 0.21329785591540662, 0.3202513601155783, 0.4187959779759185, 0.3801059305742779, 0.414905714375883, 0.5612329262833303, 0.16916653089214972, 0.7725573666541491, 0.08590847048298167, 0.26689946196043723, 0.5341330369539896, 0.5629597221974293, 0.22993221990333113, 0.006025133400169302, 0.12862111969814594, 0.6574502586028661, 0.033467506785677004, 0.7682499722580279], "type": "scatter", "marker": {"colorscale": "Viridis", "color": [0.19700265202867429, 0.5418265588820085, 0.6881460424383146, 0.43909611252834224, 0.0541288904774726, 0.640121460683488, 0.5041419863963458, 0.1460273230019622, 0.45817682921167646, 0.23031516909119687, 0.49167693695424797, 0.7805904026335428, 0.36838990434768293, 0.14259022334952343, 0.14566500744902655, 0.22388715982037222, 0.18535733605589166, 0.5378235584503375, 0.07749535905119331, 0.5084168586833716, 0.1592479764260446, 0.6729317261095901, 0.6634371013308659, 0.045030733335624684, 0.49437988649939013, 0.6487533664249954, 0.061366246214390685, 0.4409707193617006, 0.7267280531543417, 0.24884924581852108, 0.7985163100075529, 0.892468259048133, 0.8418166422337992, 0.5376936106729353, 0.5728050412932326, 0.9557029056411149, 0.8340477971901387, 0.8198131149939053, 0.15263919883653942, 0.4607586616570559, 0.6546290612398811, 0.681591728480238, 0.7820927276550874, 0.3417159705762435, 0.2967255362564827, 0.20532182776979657, 0.5618058448022387, 0.23316687319072105, 0.5188701036131819, 0.4443553614310203, 0.087973463465296, 0.2388890917371036, 0.3553339915170275, 0.51105825427109, 0.18174225276495137, 0.36671852658266835, 0.5499262291197821, 0.3536528293330785, 0.6820860712752116, 0.10210473416505272, 0.2252408843622995, 0.17771447939327045, 0.7017717765425201, 0.7434527831773882, 0.4520492865503968, 0.26299143610152065, 0.29902638787267244, 0.1137788797268442, 0.532084139890619, 0.31845515753128995, 0.6930496204966835, 0.6565815360264017, 0.524546911853256, 0.27030390528574244, 0.5645096773 ...

# %%
if not os.path.exists('images'):
    os.mkdir('images')

# %%
pio.write_image(fig, 'images\fig1.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-557904b820fe> in <module>()
# ----> 1 pio.write_image(fig, 'images\fig1.png')
#
# c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\plotly\io\_orca.py in write_image(fig, file, format, scale, width, height, validate)
#    1484                         width=width,
#    1485                         height=height,
# -> 1486                         validate=validate)
#    1487
#    1488     # Open file
#
# c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\plotly\io\_orca.py in to_image(fig, format, width, height, scale, validate)
#    1266     # Make sure orca sever is running
#    1267     # -------------------------------
# -> 1268     ensure_server()
#    1269
#    1270     # Handle defaults
#
# c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\plotly\io\_orca.py in ensure_server()
#    1137     # Validate orca executable
#    1138     if status.state == 'unvalidated':
# -> 1139         validate_executable()
#    1140
#    1141     # Acquire lock to make sure that we keep the properties of orca_state
#
# c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\plotly\io\_orca.py in validate_executable()
#     915             executable=config.executable,
#     916             formatted_path=formatted_path,
# --> 917             instructions=install_location_instructions))
#     918
#     919     # Clear NODE_OPTIONS environment variable
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'F:\YandexDisk\3.Programing\balovstvo&checking\' on the following path:
#     C:\Windows\system32
#     C:\Windows
#     C:\Windows\System32\Wbem
#     C:\Windows\System32\WindowsPowerShell\v1.0\
#     C:\ProgramData\AutomationBox\MouseRobot2\Application
#     C:\ProgramData\AutomationBox\MouseRobot2\Application\tools
#     C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
#     C:\ProgramData\chocolatey\bin
#     C:\Program Files\dotnet\
#     C:\Program Files (x86)\Windows Kits\8.1\Windows Performance Toolkit\
#     C:\tools\mingw64\bin
#     C:\Windows\SysWOW64
#     C:\Program Files (x86)\vim\vim80
#     C:\Program Files\Git\cmd
#     C:\Users\Professional\AppData\Local\Programs\Python\Python35\Scripts\
#     C:\Users\Professional\AppData\Local\Programs\Python\Python35\
#     C:\Go\bin
#     C:\Program Files\gnuplot\bin
#     C:\Program Files\PostgreSQL\10\bin
#     C:\Program Files\PostgreSQL\10\lib
#     C:\Program Files (x86)\Wolfram Research\WolframScript\
#     C:\Users\Professional\AppData\Local\Programs\Python\Python35\Scripts\
#     C:\Users\Professional\AppData\Local\Programs\Python\Python35\
#     C:\Users\Professional\AppData\Local\Microsoft\WindowsApps
#     C:\tools\mingw64\bin
#     C:\Users\Professional\go\bin
#     C:\Users\Professional\AppData\Local\Programs\MiKTeX 2.9\miktex\bin\x64\
#     c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\pywin32_system32
#     c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\pywin32_system32
#     c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\numpy\.libs
#     c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\scipy\extra-dll
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca.
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python
