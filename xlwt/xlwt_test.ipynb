# %%
import xlwt

import os
import sys
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook

# %%
WORK_DIR = 'F:\\YandexDisk\\1.Работа\\Результаты обработки'

# %%
all_files =[]
for path, dirs, files in tqdm_notebook(os.walk(WORK_DIR, topdown=False)):
    files = [x for x in files if x[-13:] == "_profiles.txt" or  x[-5:] == ".srez"] 
    all_files.extend(files)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
len(all_files)
# Out:
# 32344

# %%
all_files = list(set(all_files))
all_files = sorted(all_files, key=lambda x: datetime.datetime.strptime(x[2:6] +  ' ' + x[7:11], '%m%y %H%M'))
#all_files = sorted(all_files, key=lambda x: datetime.datetime.strptime(x[7:11], '%H%M'))

# %%
all_files[:10]
# Out:
# ['130210_0531+21_00_profiles.txt',
#  '150910_0531+21_00_profiles.txt',
#  '300910_0531+21_00_profiles.txt',
#  '210910_0531+21_00_profiles.txt',
#  '160910_0531+21_00_profiles.txt',
#  '220910_0531+21_00_profiles.txt',
#  '100910_0531+21_00_profiles.txt',
#  '090910_0531+21_00_profiles.txt',
#  '230910_0531+21_00_profiles.txt',
#  '290910_0531+21_00_profiles.txt']

# %%
book = xlwt.Workbook(encoding='utf-8', style_compression=2)
    
color = {'colour_42': (0x21, 204, 250, 204),
         'colour_50': (0x22, 153, 204, 0),
         'colour_10': (0x23, 255, 0, 0),
         'colour_11': (0x24, 0, 255, 0),
         'colour_13': (0x25, 255, 255, 0),
         'colour_24': (0x26, 153, 153, 255),
         'colour_12': (0x27, 0, 0, 255),
         'colour_20': (0x28, 128, 0, 128),
         'colour_53': (0x29, 255, 102, 0),
         'colour_23': (0x30, 128, 128, 128),
         'colour_16': (0x31, 128, 0, 0),
         'colour_15': (0x32, 0, 255, 255),
         'colour_58': (0x33, 0, 51, 0),
         'colour_22': (0x34, 192, 192, 192),
         'colour_45': (0x35, 255, 153, 204)
        }


color_name = ['colour_42', 'color_def', 'colour_50', 'color_def', 'color_def', 'colour_10', 'colour_11', 
              'colour_11', 'colour_13', 'colour_24', 'colour_12', 'colour_20', 'color_def', 'colour_53',
              'colour_23', 'colour_16', 'colour_15', 'colour_58', 'colour_22', 'colour_45']
legend_sing = ['+', ' ', ' ', '!...!!..!!!', '?', ' ', ' ', '50', ' ', ' ', ' ', ' ', '*', 
               ' ', ' ', ' ', ' ', ' ', ' ', ' ']

legend_dis = [ 'Наблюдения произведены, обработаны в PV и др. Ничего интересного', 
              'Наблюдения не были произведены',
              'Обнаружен ИИ сильно превышающий СП по S/N (или нечто интересное)',
              'Степень интересности события (зависит от конкретного пульсара)',
              'Нечто неидентифицируемое (странные помехи и т.п.)',
              'Наблюдения произведены, но средний профиль не формируется',
              'Обнаружен ГИ',
              'Максимальное превышение амплитуды среднего профиля ИИ',
              'Необработанные данные',
              'Данные обработаны в RaP, но не обработаны в программах Смирновой ТВ',
              'Сформированый СП находится в невыгодном, для анализа, положении',
              'Проблемы с файлом',
              'Большое количество помех (или одна, но сильная)',
              'Произведена калибровка',
              'Планируемые наблюдения',
              'Программа тайминга',
              'Копии данных  от наблюдателей',
              'ADC',
              'Наблюдения планировались, но совершены не были',
              'Программа SMPR'
             ]

for key in color:
        xlwt.add_palette_colour(key, color[key][0])
        book.set_colour_RGB(color[key][0], 
                            color[key][1], 
                            color[key][2], 
                            color[key][3])

# %%
def write_legend(sheet):

    first_row_idx = max(pulsar_col.items())[1] + 3
    for col, leg_s, leg_d in zip(color_name, legend_sing, legend_dis):
        if col != 'color_def':
            
            sheet.write(first_row_idx, 0, leg_s, 
                        style= xlwt.easyxf('pattern: pattern solid, fore_colour ' +  col + '; \
                        borders: top_color black, bottom_color black, right_color black, \
                        left_color black, left thin, right thin, top thin, \
                        bottom thin; align: horiz center, vert center;')) 
            
            sheet.write_merge(first_row_idx, first_row_idx, 1, 17, 
                              leg_d, 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz left, vert center;'))
            
            sheet.write_merge(first_row_idx, first_row_idx, 18, 23, 
                              str(color[col][1:])[1:-1], 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz center, vert center;'))
            
            sheet.write_merge(first_row_idx, first_row_idx, 24, 25, col[-2:], 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz center, vert center;'))
            
        else:
            
            sheet.write(first_row_idx, 0, leg_s,
                        style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                        right_color black, left_color black, left thin, right thin, \
                        top thin, bottom thin; align: horiz center, vert center;'))
            
            sheet.write_merge(first_row_idx, first_row_idx, 1, 17, 
                              leg_d, 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz left, vert center;'))
            sheet.write_merge(first_row_idx, first_row_idx, 18, 23, 
                              ' ', 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz center, vert center;'))
            sheet.write_merge(first_row_idx, first_row_idx, 24, 25, ' ', 
                              style= xlwt.easyxf('borders: top_color black, bottom_color black, \
                              right_color black, left_color black, left thin, right thin, top thin, \
                              bottom thin; align: horiz center, vert center;'))
        first_row_idx += 1
    return None

# %%
for file in tqdm_notebook(all_files):
    
    day = file[:2]
    month = file[2:4]
    year = file[4:6]
    name = file[7:14]
    
    puls_month = set([a[7:14] for a in all_files if a[2:6] == file[2:6]])
    try:
        sheet = book.add_sheet(month + '.20' + year)
        start_index_row = 2
        pulsar_col = {}
        sheet.write(0, 1, 'Дата')
        sheet.write(1, 0, 'Пульсар')
        try:
            for i in range(1, 32):
                col = sheet.col(i+1)
                col.width = 956
                val = None
                if len(str(i)) > 1:
                    val = str(i)
                else:
                    val = '0' + str(i)
            
                sheet.write_merge(0, 1, i+1, i+1,  val, style= xlwt.easyxf('borders: \
                top_color black, bottom_color black, right_color black, left_color black,\
                                  left thin, right thin, top thin, bottom thin; \
                                  align: horiz center, vert center;')) 
        except:
            e = sys.exc_info()[1]
            print(e.args[0])
            break
            
    except Exception:
        pass
    
    
    if name not in pulsar_col:
        pulsar_col[name] = start_index_row
        row = sheet.row(start_index_row)
        row.height = 1956
        sheet.write(start_index_row, 0, 'PSR_B'+ name) 
        sheet.write(start_index_row, int(day)+1, '+')
        start_index_row += 1
    else:
        try:
            sheet.write(pulsar_col[name], int(day)+1, '+')
        except Exception:
            print(file)
    
    if len(pulsar_col) == len(puls_month):
        try:
            write_legend(sheet)
        except Exception:
            continue
    else:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=28825), HTML(value='')))
# 280712_1957+20_00_profiles.txt
# 061012_0031-07_01_profiles.txt
# 290113_0809+74_01_profiles.txt
# 250213_0950+08_01_profiles.txt
# 180214_0919+06_00.srez
# 100814_0919+06_00_profiles.txt
# 260814_0919+06_00.srez
# 210814_0919+06_00_profiles.txt
# 160814_0919+06_00_profiles.txt
# 040814_0919+06_00_profiles.txt
# 240814_0919+06_00_profiles.txt
# 270814_0919+06_00.srez
# 090814_0919+06_00.srez
# 030814_0919+06_00_profiles.txt
# 140814_0919+06_00.srez
# 120814_0919+06_00.srez
# 050814_0919+06_00.srez
# 180814_0919+06_00.srez
# 310814_0919+06_00.srez
# 250814_0919+06_00.srez
# 280814_0919+06_00.srez
# 130814_0919+06_00_profiles.txt
# 200814_0919+06_00_profiles.txt
# 020814_0919+06_00.srez
# 230814_0919+06_00.srez
# 300814_0919+06_00_profiles.txt
# 170814_0919+06_00_profiles.txt
# 060814_0919+06_00.srez
# 190814_0919+06_00.srez
# 110814_0919+06_00.srez
# 070814_0919+06_00.srez
# 140914_1112+50_00_profiles.txt
# 210115_0919+06_00.srez
# 090115_0919+06_00.srez
# 130115_0919+06_00_profiles.txt
# 140115_0919+06_00.srez
# 030115_0919+06_00.srez
# 280115_0919+06_00.srez
# 310115_0919+06_00_profiles.txt
# 040115_0919+06_00_profiles.txt
# 220115_0919+06_00.srez
# 170115_0919+06_00_profiles.txt
# 160115_0919+06_00.srez
# 240115_0919+06_00_profiles.txt
# 080115_0919+06_00.srez
# 020115_0919+06_00.srez
# 100115_0919+06_00.srez
# 300115_0919+06_00.srez
# 010115_0919+06_00_profiles.txt
# 150115_0919+06_00.srez
# 110115_0919+06_00_profiles.txt
# 270115_0919+06_00.srez
# 290115_0919+06_00_profiles.txt
# 190115_0919+06_00.srez
# 050115_0919+06_00.srez
# 230115_0919+06_00.srez
# 250115_0919+06_00.srez
# 180115_0919+06_00.srez
# 160215_0919+06_00.srez
# 180215_0919+06_00_profiles.txt
# 140215_0919+06_00.srez
# 210215_0919+06_00.srez
# 150215_0919+06_00_profiles.txt
# 120215_0919+06_00_profiles.txt
# 080215_0919+06_00_profiles.txt
# 070215_0919+06_00_profiles.txt
# 190215_0919+06_00.srez
# 100215_0919+06_00_profiles.txt
# 240215_0919+06_00_profiles.txt
# 220215_0919+06_00.srez
# 250215_0919+06_00_profiles.txt
# 280215_0919+06_00_profiles.txt
# 270215_0919+06_00.srez
# 040215_0919+06_00.srez
# 010215_0919+06_00.srez
# 020215_0919+06_00_profiles.txt
# 130215_0919+06_00_profiles.txt
# 260215_0919+06_00_profiles.txt
# 110215_0919+06_00_profiles.txt
# 200215_0919+06_00_profiles.txt
# 180315_0919+06_00.srez
# 130315_0919+06_00.srez
# 310315_0919+06_00.srez
# 020315_0919+06_00_profiles.txt
# 260315_0919+06_00.srez
# 270315_0919+06_00.srez
# 060315_0919+06_00_profiles.txt
# 070315_0919+06_00.srez
# 200315_0919+06_00_profiles.txt
# 290315_0919+06_00_profiles.txt
# 220315_0919+06_00_profiles.txt
# 140315_0919+06_00_profiles.txt
# 040315_0919+06_00.srez
# 240315_0919+06_00_profiles.txt
# 100315_0919+06_00_profiles.txt
# 110315_0919+06_00.srez
# 150315_0919+06_00.srez
# 250315_0919+06_00_profiles.txt
# 300315_0919+06_00.srez
# 190315_0919+06_00.srez
# 120315_0919+06_00.srez
# 080315_0919+06_00_profiles.txt
# 050315_0919+06_00.srez
# 280315_0919+06_00.srez
# 010315_0919+06_00.srez
# 210315_0919+06_00.srez
# 160315_0919+06_00_profiles.txt
# 020415_0919+06_00_profiles.txt
# 150415_0919+06_00.srez
# 270415_0919+06_00_profiles.txt
# 170415_0919+06_00.srez
# 210415_0919+06_00.srez
# 160415_0919+06_00_profiles.txt
# 100415_0919+06_00.srez
# 250415_0919+06_00.srez
# 180415_0919+06_00.srez
# 080415_0919+06_00.srez
# 280415_0919+06_00.srez
# 140415_0919+06_00.srez
# 130415_0919+06_00.srez
# 050415_0919+06_00_profiles.txt
# 300415_0919+06_00_profiles.txt
# 240415_0919+06_00_profiles.txt
# 070415_0919+06_00.srez
# 230415_0919+06_00_profiles.txt
# 290415_0919+06_00_profiles.txt
# 010415_0919+06_00.srez
# 110415_0919+06_00_profiles.txt
# 220415_0919+06_00_profiles.txt
# 190415_0919+06_00.srez
# 090415_0919+06_00_profiles.txt
# 080415_1237+25_01_profiles.txt
# 280515_0919+06_00_profiles.txt
# 010515_0919+06_00.srez
# 040515_0919+06_00.srez
# 220515_0919+06_00.srez
# 210515_0919+06_00.srez
# 160515_0919+06_00.srez
# 100515_0919+06_00.srez
# 060515_0919+06_00_profiles.txt
# 200515_0919+06_00.srez
# 240515_0919+06_00.srez
# 070515_0919+06_00.srez
# 130515_0919+06_00.srez
# 110515_0919+06_00_profiles.txt
# 120515_0919+06_00_profiles.txt
# 180515_0919+06_00_profiles.txt
# 270515_0919+06_00.srez
# 080515_0919+06_00_profiles.txt
# 190515_0919+06_00.srez
# 020515_0919+06_00.srez
# 140515_0919+06_00.srez
# 050515_0919+06_00_profiles.txt
# 040615_0919+06_00.srez
# 060615_0919+06_00.srez
# 190615_0919+06_00.srez
# 200615_0919+06_00.srez
# 250615_0919+06_00_profiles.txt
# 050615_0919+06_00.srez
# 180615_0919+06_00.srez
# 300615_0919+06_00.srez
# 140615_0919+06_00_profiles.txt
# 130615_0919+06_00.srez
# 110615_0919+06_00_profiles.txt
# 270615_0919+06_00_profiles.txt
# 280615_0919+06_00_profiles.txt
# 150615_0919+06_00.srez
# 260615_0919+06_00.srez
# 290615_0919+06_00_profiles.txt
# 120615_0919+06_00.srez
# 020615_0919+06_00_profiles.txt
# 160615_0919+06_00.srez
# 220615_0919+06_00.srez
# 010615_0919+06_00.srez
# 080615_0919+06_00_profiles.txt
# 070615_0919+06_00_profiles.txt
# 240615_0919+06_00.srez
# 100615_0919+06_00.srez
# 210615_0919+06_00_profiles.txt
# 050715_0919+06_00_profiles.txt
# 080715_0919+06_00.srez
# 310715_0919+06_00.srez
# 220715_0919+06_00_profiles.txt
# 110715_0919+06_00.srez
# 100715_0919+06_00.srez
# 020715_0919+06_00.srez
# 140715_0919+06_00.srez
# 130715_0919+06_00_profiles.txt
# 250715_0919+06_00.srez
# 150715_0919+06_00_profiles.txt
# 180715_0919+06_00.srez
# 030715_0919+06_00.srez
# 010715_0919+06_00_profiles.txt
# 170715_0919+06_00_profiles.txt
# 090715_0919+06_00.srez
# 270715_0919+06_00_profiles.txt
# 160715_0919+06_00_profiles.txt
# 230715_0919+06_00.srez
# 290715_0919+06_00.srez
# 070715_0919+06_00_profiles.txt
# 300715_0919+06_00.srez
# 190715_0919+06_00_profiles.txt
# 240715_0919+06_00.srez
# 280715_0919+06_00_profiles.txt
# 040715_0919+06_00_profiles.txt
# 190815_0919+06_00.srez
# 140815_0919+06_00_profiles.txt
# 160815_0919+06_00_profiles.txt
# 070815_0919+06_00_profiles.txt
# 060815_0919+06_00.srez
# 290815_0919+06_00_profiles.txt
# 280815_0919+06_00_profiles.txt
# 310815_0919+06_00.srez
# 040815_0919+06_00_profiles.txt
# 200815_0919+06_00.srez
# 150815_0919+06_00.srez
# 180815_0919+06_00.srez
# 240815_0919+06_00.srez
# 270815_0919+06_00.srez
# 130815_0919+06_00.srez
# 110815_0919+06_00_profiles.txt
# 100815_0919+06_00.srez
# 120815_0919+06_00_profiles.txt
# 260815_0919+06_00.srez
# 010815_0919+06_00.srez
# 020815_0919+06_00_profiles.txt
# 080815_0919+06_00.srez
# 300815_0919+06_00_profiles.txt
# 050815_0919+06_00_profiles.txt
# 250815_0919+06_00.srez
# 220815_0919+06_00.srez
# 210815_0919+06_00.srez
# 160915_0919+06_00.srez
# 130915_0919+06_00.srez
# 070915_0919+06_00_profiles.txt
# 110915_0919+06_00.srez
# 050915_0919+06_00.srez
# 240915_0919+06_00_profiles.txt
# 020915_0919+06_00.srez
# 290915_0919+06_00.srez
# 220915_0919+06_00_profiles.txt
# 250915_0919+06_00.srez
# 280915_0919+06_00_profiles.txt
# 040915_0919+06_00_profiles.txt
# 010915_0919+06_00.srez
# 180915_0919+06_00.srez
# 210915_0919+06_00_profiles.txt
# 260915_0919+06_00.srez
# 270915_0919+06_00.srez
# 150915_0919+06_00_profiles.txt
# 120915_0919+06_00_profiles.txt
# 140915_0919+06_00.srez
# 080915_0919+06_00.srez
# 300915_0919+06_00.srez
# 200915_0919+06_00_profiles.txt
# 190915_0919+06_00.srez
# 060915_0919+06_00.srez
# 271015_0154+61_01_profiles.txt
# 041015_0919+06_00_profiles.txt
# 171015_0919+06_00.srez
# 031015_0919+06_00.srez
# 021015_0919+06_00_profiles.txt
# 011015_0919+06_00.srez
# 091015_0919+06_00_profiles.txt
# 111015_0919+06_00.srez
# 051015_0919+06_00.srez
# 121015_0919+06_00.srez
# 061015_0919+06_00_profiles.txt
# 081015_0919+06_00_profiles.txt
# 141015_0919+06_00.srez
# 071015_0919+06_00_profiles.txt
# 161015_0919+06_00_profiles.txt
# 131015_0919+06_00.srez
# 101015_0919+06_00.srez
# 191015_0919+06_00_profiles.txt
# 151015_0919+06_00.srez
# 181015_0919+06_00_profiles.txt
# 131115_0919+06_00_profiles.txt
# 201115_0919+06_00_profiles.txt
# 261115_0919+06_00.srez
# 161115_0919+06_00_profiles.txt
# 121115_0919+06_00.srez
# 041115_0919+06_00.srez
# 151115_0919+06_00_profiles.txt
# 141115_0919+06_00_profiles.txt
# 241115_0919+06_00_profiles.txt
# 031115_0919+06_00.srez
# 091115_0919+06_00.srez
# 221115_0919+06_00_profiles.txt
# 071115_0919+06_00_profiles.txt
# 011115_0919+06_00.srez
# 051115_0919+06_00.srez
# 211115_0919+06_00.srez
# 231115_0919+06_00.srez
# 101115_0919+06_00_profiles.txt
# 171115_0919+06_00.srez
# 111115_0919+06_00.srez
# 301115_0919+06_00.srez
# 061115_0919+06_00.srez
# 271115_0919+06_00.srez
# 251115_0919+06_00_profiles.txt
# 021115_0919+06_00.srez
# 291115_0919+06_00_profiles.txt
# 281115_0919+06_00_profiles.txt
# 181115_0919+06_00.srez
# 081115_0919+06_00.srez
# 191115_0919+06_00_profiles.txt
# 071215_0919+06_00.srez
# 051215_0919+06_00.srez
# 061215_0919+06_00.srez
# 161215_0919+06_00.srez
# 301215_0919+06_00.srez
# 281215_0919+06_00.srez
# 111215_0919+06_00.srez
# 291215_0919+06_00.srez
# 131215_0919+06_00_profiles.txt
# 021215_0919+06_00.srez
# 231215_0919+06_00.srez
# 251215_0919+06_00_profiles.txt
# 201215_0919+06_00_profiles.txt
# 211215_0919+06_00_profiles.txt
# 081215_0919+06_00.srez
# 181215_0919+06_00_profiles.txt
# 121215_0919+06_00_profiles.txt
# 271215_0919+06_00_profiles.txt
# 221215_0919+06_00.srez
# 011215_0919+06_00_profiles.txt
# 101215_0919+06_00_profiles.txt
# 031215_0919+06_00_profiles.txt
# 241215_0919+06_00.srez
# 091215_0919+06_00_profiles.txt
# 311215_0919+06_00.srez
# 171215_0919+06_00_profiles.txt
# 041215_0919+06_00.srez
# 261215_0919+06_00_profiles.txt
# 141215_0919+06_00_profiles.txt
# 191215_0919+06_00_profiles.txt
# 151215_0919+06_00.srez
# 210116_0136+57_00.srez
# 190116_0136+57_00_profiles.txt
# 230116_0136+57_00_profiles.txt
# 250116_0136+57_00_profiles.txt
# 170116_0136+57_00_profiles.txt
# 240116_0136+57_00.srez
# 220116_0136+57_00_profiles.txt
# 200116_0136+57_00.srez
# 280116_0136+57_00.srez
# 290116_0809+74_01_profiles.txt
# 110116_0919+06_00_profiles.txt
# 070116_0919+06_00.srez
# 010116_0919+06_00.srez
# 250116_0919+06_00_profiles.txt
# 180116_0919+06_00.srez
# 200116_0919+06_00_profiles.txt
# 050116_0919+06_00.srez
# 300116_0919+06_00.srez
# 170116_0919+06_00.srez
# 130116_0919+06_00.srez
# 060116_0919+06_00_profiles.txt
# 210116_0919+06_00.srez
# 040116_0919+06_00_profiles.txt
# 020116_0919+06_00_profiles.txt
# 100116_0919+06_00.srez
# 080116_0919+06_00_profiles.txt
# 090116_0919+06_00_profiles.txt
# 150116_0919+06_00_profiles.txt
# 140116_0919+06_00.srez
# 030116_0919+06_00.srez
# 290116_0919+06_00_profiles.txt
# 220116_0919+06_00_profiles.txt
# 230116_0919+06_00.srez
# 120116_0919+06_00.srez
# 160116_0919+06_00.srez
# 260116_0919+06_00.srez
# 280116_0919+06_00_profiles.txt
# 240116_0919+06_00_profiles.txt
# 230216_0919+06_00_profiles.txt
# 070216_0919+06_00_profiles.txt
# 180216_0919+06_01_profiles.txt
# 040216_0919+06_00_profiles.txt
# 080216_0919+06_00_profiles.txt
# 100216_0919+06_00_profiles.txt
# 180216_0919+06_00.srez
# 280216_0919+06_00.srez
# 050216_0919+06_00_profiles.txt
# 260216_0919+06_00.srez
# 140216_0919+06_00.srez
# 170216_0919+06_00.srez
# 030216_0919+06_00.srez
# 290216_0919+06_00.srez
# 090216_0919+06_00_profiles.txt
# 220216_0919+06_00.srez
# 020216_0919+06_00_profiles.txt
# 130216_0919+06_00.srez
# 270216_0919+06_00.srez
# 250216_0919+06_00.srez
# 110216_0919+06_00.srez
# 060216_0919+06_00.srez
# 240216_0919+06_00.srez
# 180216_0919+06_00_profiles.txt
# 160216_0919+06_00_profiles.txt
# 190216_0919+06_00.srez
# 020316_0919+06_00_profiles.txt
# 110316_0919+06_00_profiles.txt
# 160316_0919+06_00.srez
# 250316_0919+06_00.srez
# 060316_0919+06_00.srez
# 290316_0919+06_00_profiles.txt
# 310316_0919+06_00_profiles.txt
# 120316_0919+06_00.srez
# 210316_0919+06_00.srez
# 180316_0919+06_00_profiles.txt
# 080316_0919+06_00.srez
# 040316_0919+06_00_profiles.txt
# 260316_0919+06_00_profiles.txt
# 270316_0919+06_00_profiles.txt
# 050316_0919+06_00_profiles.txt
# 010316_0919+06_00_profiles.txt
# 150316_0919+06_00.srez
# 280316_0919+06_00.srez
# 190316_0919+06_00_profiles.txt
# 090316_0919+06_00.srez
# 200316_0919+06_00.srez
# 130316_0919+06_00_profiles.txt
# 100316_0919+06_00_profiles.txt
# 140316_0919+06_00.srez
# 240316_0919+06_00.srez
# 220316_0919+06_00_profiles.txt
# 230316_0919+06_00_profiles.txt
# 070316_0919+06_00.srez
# 030316_0919+06_00.srez
# 300316_0919+06_00_profiles.txt
# 170316_0919+06_00_profiles.txt
# 170316_1112+50_01_profiles.txt
# 220316_1133+16_00_profiles.txt
# 230416_0919+06_00_profiles.txt
# 050416_0919+06_00_profiles.txt
# 200416_0919+06_00_profiles.txt
# 210416_0919+06_00.srez
# 060416_0919+06_00_profiles.txt
# 150416_0919+06_00.srez
# 020416_0919+06_00_profiles.txt
# 130416_0919+06_00_profiles.txt
# 300416_0919+06_00.srez
# 140416_0919+06_00_profiles.txt
# 250416_0919+06_00_profiles.txt
# 270416_0919+06_00.srez
# 170416_0919+06_00_profiles.txt
# 240416_0919+06_00.srez
# 280416_0919+06_00.srez
# 070416_0919+06_00_profiles.txt
# 010416_0919+06_00.srez
# 080416_0919+06_00_profiles.txt
# 180416_0919+06_00.srez
# 100416_0919+06_00_profiles.txt
# 190416_0919+06_00_profiles.txt
# 260416_0919+06_00.srez
# 120416_0919+06_00_profiles.txt
# 220416_0919+06_00_profiles.txt
# 090416_0919+06_00.srez
# 110416_0919+06_00.srez
# 160416_0919+06_00_profiles.txt
# 080416_1237+25_00_profiles.txt
# 070416_1237+25_01_profiles.txt
# 200516_0919+06_00.srez
# 130516_0919+06_00_profiles.txt
# 110516_0919+06_00_profiles.txt
# 050516_0919+06_00.srez
# 060516_0919+06_00.srez
# 100516_0919+06_00_profiles.txt
# 080516_0919+06_00.srez
# 010516_0919+06_00_profiles.txt
# 120516_0919+06_00.srez
# 280516_0919+06_00.srez
# 090516_0919+06_00_profiles.txt
# 170516_0919+06_00_profiles.txt
# 160516_0919+06_00_profiles.txt
# 040516_0919+06_00.srez
# 290516_0919+06_00.srez
# 250516_0919+06_00.srez
# 070516_0919+06_00_profiles.txt
# 180516_0919+06_00.srez
# 150516_0919+06_00.srez
# 220516_0919+06_00_profiles.txt
# 240516_0919+06_00.srez
# 140516_0919+06_00_profiles.txt
# 230516_0919+06_00.srez
# 210516_0919+06_00.srez
# 300516_0919+06_00_profiles.txt
# 270516_0919+06_00.srez
# 190516_0919+06_00_profiles.txt
# 210516_1530+27_00_profiles.txt
# 050616_0919+06_00.srez
# 030616_0919+06_00_profiles.txt
# 040616_0919+06_00.srez
# 070616_0919+06_00_profiles.txt
# 060616_0919+06_00.srez
# 010616_0919+06_00.srez
# 310716_2011+38_00_profiles.txt
# 050816_2032+41_00_profiles.txt
# 170816_2110+27_00.srez
# 211016_0138+33_01_profiles.txt
# 131116_0303+22_01_profiles.txt
# 290117_0809+74_00_profiles.txt
# 250217_0950+08_01_profiles.txt
# 280217_1005+30_00_profiles.txt
# 170317_1112+50_01_profiles.txt
# 230317_1133+16_00_profiles.txt
# 030717_0834+06_00_profiles.txt
# 241017_0146+31_00_profiles.txt
# 211017_2310+42_00.srez
# 261017_2310+42_00.srez
# 251017_2310+42_00.srez
# 231017_2310+42_00_profiles.txt
# 221017_2310+42_00_profiles.txt
# 271017_2310+42_00.srez
# 241017_2310+42_00.srez
# 281017_2310+42_00_profiles.txt
# 021117_0220+36_00_profiles.txt
# 081117_2310+42_00_profiles.txt
# 011117_2310+42_00_profiles.txt
# 071117_2310+42_00_profiles.txt
# 021117_2310+42_00_profiles.txt
# 031117_2310+42_00_profiles.txt
# 061117_2310+42_00_profiles.txt
# 041117_2310+42_00_profiles.txt
# 051117_2310+42_00.srez
# 201217_0525+21_00_profiles.txt
# 190218_0928+30_01_profiles.txt
# 170318_1112+50_01_profiles.txt
# 230318_1133+16_00_profiles.txt

# %%
book.save('xlwt_test.xls')
